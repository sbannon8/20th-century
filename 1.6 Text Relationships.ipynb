# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Load Data

# %% [markdown]
# #### Wiki -------------------------------

# %%
# Load the wiki text
with open('20th_century_wiki.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

wiki = nlp(data)

# %%
from IPython.display import display

# %%
# Visualize identified entities
displacy.render([wiki[273:20000]], style="ent", jupyter=True)

# does not work
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Visualize identified entities
# ----> 2 displacy.render([wiki[273:20000]], style="ent", jupyter=True)
#
# File ~\anaconda3\envs\20th_century\Lib\site-packages\spacy\displacy\__init__.py:69, in render(docs, style, page, minify, jupyter, options, manual)
#      65     html = RENDER_WRAPPER(html)
#      66 if jupyter or (jupyter is None and is_in_jupyter()):
#      67     # return HTML rendered by IPython display()
#      68     # See #4840 for details on span wrapper to disable mathjax
# ---> 69     from IPython.core.display import HTML, display
#      71     return display(HTML('<span class="tex2jax_ignore">{}</span>'.format(html)))
#      72 return html
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (C:\Users\steve\anaconda3\envs\20th_century\Lib\site-packages\IPython\core\display.py)

# %%
df_sentences = []

# Loop through sentences, get entity list for each sentence
for sent in wiki.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent.text, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0      Key events of the 20th century - Wikipedia...
# 1  1 Historic events in the 20th century     Togg...
# 2  World War II (1939â€“1945)       1.3.1 The war...
# 3  Blitzkrieg         1.3.3 Operation Barbarossa ...
# 4  Turning tides         1.3.5 Operation Overlord...
# 5  Allied offensive         1.3.10 Final days    ...
# 6  The Nuclear Age begins           1.4 The post-...
# 7   The end of empires: decolonization         1.4.2
# 8  The Cold War (1947â€“1991)         1.4.3 War b...
# 9  The space race         1.4.5 The end of the Co...
#
#                                             entities
# 0  [the 20th century - Wikipedia                 ...
# 1  [the 20th century, the 20th century, the begin...
# 2             [World War II, 1.3.1, Europe         ]
# 3                         [Blitzkrieg         1.3.3]
# 4  [the Pacific       1.3.7.1 Background         ...
# 5                     [The Holocaust         1.3.12]
# 6                                              [1.4]
# 7                                                 []
# 8                   [The Cold War, 1.4.3 War, 1.4.4]
# 9                            [the Cold War         ]

# %% [markdown]
# #### Countries List -------------------------------

# %%
# import countries text file
path = 'C:/Users/steve/20th-century'
countries_df = pd.read_csv(os.path.join(path, 'countries_list_20th_century.csv'))

# %%
countries_df.head()
# Out:
#    Unnamed: 0   country_name
# 0           1   Afghanistan
# 1           2       Albania
# 2           3       Algeria
# 3           4       Andorra
# 4           5        Angola

# %%
countries_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
countries_df['country_name'] = countries_df['country_name'].str.strip().str.replace(r'\s+', ' ', regex=True)

# %%
countries_df.head()
# Out:
#   country_name
# 0  Afghanistan
# 1      Albania
# 2      Algeria
# 3      Andorra
# 4       Angola

# %% [markdown]
# ### Filter Data

# %%
# Function to filter out entities not of interest
def filter_entity(ent_list, countries_df):
       return [ent for ent in ent_list
                  if ent in list(countries_df['country_name'])]

# %%
df_sentences['country_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, countries_df))

# %%
# Filter out sentences that don’t have any country entities
df_sentences_filtered = df_sentences[df_sentences['country_entities'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 1134  ^ "The division of Germany â€“ The Cold War (1...
# 1166  "The forgotten violence that helped India brea...
# 1170  "Indian Independence Day: everything you need ...
# 1179  ^ "The Philippines, 1898â€“1946 | US House of ...
# 1249  The Moldovans: Romania, Russia, and the Politi...
# 1314  "Selling 'Operation Passage to Freedom': Dr. T...
# 1349  "Stuck in Endless Preliminaries: Vietnam and t...
# 1618  "Anti-American Behavior in the Middle East: Ev...
# 1623    The Rise of China and India: A New Asian Drama.
# 1624                       Singapore: World Scientific.
#
#                                                entities   country_entities
# 1134                            [Germany, The Cold War]          [Germany]
# 1166                                            [India]            [India]
# 1170  [Indian Independence Day, Partition, India, Pa...  [India, Pakistan]
# 1179  [Philippines, 1898â€“1946, US House of Represe...      [Philippines]
# 1249  [Moldovans, Romania, Russia, the Politics of C...  [Romania, Russia]
# 1314  [Thomas Dooley, the Religious Overtones of Ear...          [Vietnam]
# 1349  [Vietnam, the Battle of the Paris Peace Table,...          [Vietnam]
# 1618          [Anti-American, the Middle East, Lebanon]          [Lebanon]
# 1623                    [China, India, New Asian Drama]            [India]
# 1624                      [Singapore, World Scientific]        [Singapore]

# %% [markdown]
# ### Relationship Analysis

# %%
# Defining relationships with a sliding window
window_size = 5
relationships = []

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i + window_size, df_sentences_filtered.index[-1])
    
    # Flatten the list of country entities in the window
    country_list = sum(df_sentences_filtered.loc[i:end_i, 'country_entities'].tolist(), [])

    # Remove duplicates that are adjacent
    country_unique = [country_list[j] for j in range(len(country_list))
                      if j == 0 or country_list[j] != country_list[j - 1]]
    
    # If more than one unique country, define edges
    if len(country_unique) > 1:
        for idx, a in enumerate(country_unique[:-1]):
            b = country_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

relationship_df
# Out:
#       source     target
# 0     France    Austria
# 1    Austria     Russia
# 2     France    Austria
# 3    Austria     Russia
# 4     Russia    Germany
# ..       ...        ...
# 588    India  Singapore
# 589    India  Singapore
# 590    India  Singapore
# 591    India  Singapore
# 592    India  Singapore
#
# [593 rows x 2 columns]

# %%
# Sort the cases with a- >b and b- >a
relationships_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationships_df.head(5)
# Out:
#     source  target
# 0  Austria  France
# 1  Austria  Russia
# 2  Austria  France
# 3  Austria  Russia
# 4  Germany  Russia

# %%
relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

relationship_df.head(10)
# Out:
#     source   target  value
# 0   France  Austria      1
# 1  Austria   Russia      1
# 2   Russia  Germany      1
# 3  Germany   Russia      1
# 4  Germany    Italy      1
# 5    Italy  Germany      1
# 6  Germany  Austria      1
# 7  Austria  Germany      1
# 8  Germany    Spain      1
# 9   France   Poland      1

# %% [markdown]
# ### Export Data

# %%
file_path = os.path.join(path, "relationships.csv")
relationship_df.to_csv(file_path, index=False)
